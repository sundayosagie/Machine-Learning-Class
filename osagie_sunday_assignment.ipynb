# %%
# Data Science/Machine Learning Class - Github Assignment
# **Name:** Osagie Sunday

# Import libraries
import matplotlib.pyplot as plt
import numpy as np

# Data Definition
labels = ['A', 'B', 'C', 'D']
values = [10, 20, 15, 25]

# Bar Chart Plot
plt.bar(labels, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart')
plt.show()

# Brief Description
### Plot Description
# This bar chart was created using Matplotlib.
# It fulfills the assignment requirement for me to create any plot in a Jupyter Notebook.
